# %% [markdown]
# # Sign Language Alphabet Recognizer - Training on Colab
#
# This notebook trains the SLR model using InceptionV3 transfer learning.

# %% [markdown]
# ## 1. Mount Google Drive (Optional - to save trained model)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Clone the Repository

# %%
# !git clone https://github.com/YOUR_USERNAME/YOUR_REPO.git
# %cd YOUR_REPO

# %% [markdown]
# ## 3. Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 4. Check GPU Availability

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.__version__)

# %% [markdown]
# ## 5. Train the Model

# %%
# !python train.py \
  --bottleneck_dir=logs/bottlenecks \
  --how_many_training_steps=2000 \
  --model_dir=inception \
  --summaries_dir=logs/training_summaries/basic \
  --output_graph=logs/trained_graph.pb \
  --output_labels=logs/trained_labels.txt \
  --image_dir=./dataset

# %% [markdown]
# ## 6. Save Trained Model to Google Drive

# %%
# !cp -r logs /content/drive/MyDrive/slr_model_logs

# %% [markdown]
# ## 7. Download Trained Model (Alternative)

# %%
from google.colab import files
# !zip -r trained_model.zip logs/
files.download('trained_model.zip')

# %% [markdown]
# ## 8. Test Classification (Optional)

# %%
# Test with an image from the dataset
# !python classify.py dataset/A/1.jpg
